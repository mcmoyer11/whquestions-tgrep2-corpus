# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("/Users/momo/Dropbox/Stanford/whquestions-tgrep2/experiments/01_experiment/01_pilot/results/rscripts/df_nested.csv").drop(columns="Unnamed: 0")

# %%
df.head()
# Out:
#    workerid proliferate.condition           order          response  \
# 0        38            condition1             NaN  ['Mary', 'Mary']
# 1        38            condition1  a-the-all-some    ['all', False]
# 2        38            condition1  a-the-all-some      ['a', False]
# 3        38            condition1  a-the-all-some    ['all', False]
# 4        38            condition1  a-the-all-some    ['the', False]
#
#    slide_number_in_experiment   tgrep_id catch_trials  \
# 0                           1  bot_check           []
# 1                           3   example1           []
# 2                           4   example2           []
# 3                           5   example1           []
# 4                           6   example4           []
#
#    subject_information.age subject_information.asses  \
# 0                     41.0                       Yes
# 1                     41.0                       Yes
# 2                     41.0                       Yes
# ...

# %%
df_split = df.response.apply(pd.Series).merge(df, left_index = True, right_index = True)

# %%
df_split.head()
# Out:
#                   0  workerid proliferate.condition           order  \
# 0  ['Mary', 'Mary']        38            condition1             NaN
# 1    ['all', False]        38            condition1  a-the-all-some
# 2      ['a', False]        38            condition1  a-the-all-some
# 3    ['all', False]        38            condition1  a-the-all-some
# 4    ['the', False]        38            condition1  a-the-all-some
#
#            response  slide_number_in_experiment   tgrep_id catch_trials  \
# 0  ['Mary', 'Mary']                           1  bot_check           []
# 1    ['all', False]                           3   example1           []
# 2      ['a', False]                           4   example2           []
# 3    ['all', False]                           5   example1           []
# 4    ['the', False]                           6   example4           []
#
#    subject_information.age subject_information.asses  ...  \
# 0                     41.0                       Yes  ...
# ...

# %%
df[['response','strange']] = pd.DataFrame(df.response.tolist(), index= df.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-2e062cf62f07> in <module>
# ----> 1 df[['response','strange']] = pd.DataFrame(df.response.tolist(), index= df.index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
# ...

# %%
pd.DataFrame(df["response"].to_list(), columns=['response', 'strange'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1653                 blocks = [
# -> 1654                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1655                 ]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3052
# -> 3053     return klass(values, ndim=ndim, placement=placement)
#    3054
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#    2600
# -> 2601         super().__init__(values, ndim=ndim, placement=placement)
#    2602
#
# ...

# %%
df2 = df.response.apply(pd.Series)
# df2.columns = ['response', 'strange']

# %%
df2.head()
# Out:
#                   0
# 0  ['Mary', 'Mary']
# 1    ['all', False]
# 2      ['a', False]
# 3    ['all', False]
# 4    ['the', False]

# %%
df.response.dtype
# Out:
# dtype('O')

# %%
df.response = df.response.apply(lambda x: re.sub(r'[^\w\s]','',x))

# %%
df.head()
# Out:
#    workerid proliferate.condition           order   response  \
# 0        38            condition1             NaN  Mary Mary
# 1        38            condition1  a-the-all-some  all False
# 2        38            condition1  a-the-all-some    a False
# 3        38            condition1  a-the-all-some  all False
# 4        38            condition1  a-the-all-some  the False
#
#    slide_number_in_experiment   tgrep_id catch_trials  \
# 0                           1  bot_check           []
# 1                           3   example1           []
# 2                           4   example2           []
# 3                           5   example1           []
# 4                           6   example4           []
#
#    subject_information.age subject_information.asses  \
# 0                     41.0                       Yes
# 1                     41.0                       Yes
# 2                     41.0                       Yes
# ...

# %%
df_res = pd.DataFrame(df.response.str.split(' ',1).tolist(), columns = ['response','is_strange'])

# %%
total = df_res.merge(df, left_index = True, right_index = True).drop(columns="response_y").rename(columns={"response_x": "response"})

# %%
total.head()
# Out:
#   response is_strange  workerid proliferate.condition           order  \
# 0     Mary       Mary        38            condition1             NaN
# 1      all      False        38            condition1  a-the-all-some
# 2        a      False        38            condition1  a-the-all-some
# 3      all      False        38            condition1  a-the-all-some
# 4      the      False        38            condition1  a-the-all-some
#
#    slide_number_in_experiment   tgrep_id catch_trials  \
# 0                           1  bot_check           []
# 1                           3   example1           []
# 2                           4   example2           []
# 3                           5   example1           []
# 4                           6   example4           []
#
#    subject_information.age subject_information.asses  ...  \
# 0                     41.0                       Yes  ...
# 1                     41.0                       Yes  ...
# ...

# %%
total.to_csv("total_unnested.csv",header=True)

# %%
df[["response","strange"]] = df.response.str.split(" ",expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-aff07db35f12> in <module>
# ----> 1 df[["response","strange"]] = df.response.str.split(" ",expand=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
# ...

# %%
# df.response.apply(pd.Series).merge(df, left_index = True, right_index = True)
# Out:
#                     0  workerid proliferate.condition           order  \
# 0    ['Mary', 'Mary']        38            condition1             NaN
# 1      ['all', False]        38            condition1  a-the-all-some
# 2        ['a', False]        38            condition1  a-the-all-some
# 3      ['all', False]        38            condition1  a-the-all-some
# 4      ['the', False]        38            condition1  a-the-all-some
# ..                ...       ...                   ...             ...
# 557   ['some', False]        36            condition1  the-some-a-all
# 558    ['the', False]        36            condition1  the-some-a-all
# 559      ['a', False]        36            condition1  the-some-a-all
# 560   ['some', False]        36            condition1  the-some-a-all
# 561      ['a', False]        36            condition1  the-some-a-all
#
#              response  slide_number_in_experiment   tgrep_id catch_trials  \
# ...

# %%
for i in [0,1]:
    df['response{}'.format(str(i+1))]=[k[i] if isinstance(k,list) else k for k in df['response']]

# %%
df.head()
# Out:
#    workerid proliferate.condition           order          response  \
# 0        38            condition1             NaN  ['Mary', 'Mary']
# 1        38            condition1  a-the-all-some    ['all', False]
# 2        38            condition1  a-the-all-some      ['a', False]
# 3        38            condition1  a-the-all-some    ['all', False]
# 4        38            condition1  a-the-all-some    ['the', False]
#
#    slide_number_in_experiment   tgrep_id catch_trials  \
# 0                           1  bot_check           []
# 1                           3   example1           []
# 2                           4   example2           []
# 3                           5   example1           []
# 4                           6   example4           []
#
#    subject_information.age subject_information.asses  \
# 0                     41.0                       Yes
# 1                     41.0                       Yes
# 2                     41.0                       Yes
# ...
